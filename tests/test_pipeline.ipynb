# %%
from etl.ingest import ingest_data
from etl.mfcc_pyspark import process_mfcc

data = ingest_data("data/raw")
df = process_mfcc(data)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 from etl.ingest import ingest_data
#       2 from etl.mfcc_pyspark import process_mfcc
#       4 data = ingest_data("data/raw")
#
# ModuleNotFoundError: No module named 'etl'

# %%
DESKTOP-D5DRVDO.localdomain
 ▶ Log message source details
2026-05-21 12:39:32,747 - etl.save_parquet - INFO - Guardado completado correctamente
[2026-05-21, 15:39:00 UTC] {local_task_job_runner.py:123} ▶ Pre task execution logs
[2026-05-21, 15:39:00 UTC] {subprocess.py:78} INFO - Tmp dir root location: /tmp
[2026-05-21, 15:39:00 UTC] {subprocess.py:88} INFO - Running command: ['/usr/bin/bash', '-c', '\n        cd /home/tolaba/end-to-end-pipeline-audio-IA &&\n        source .venv/bin/activate &&\n        python main.py\n        ']
[2026-05-21, 15:39:00 UTC] {subprocess.py:99} INFO - Output:
[2026-05-21, 15:39:00 UTC] {subprocess.py:106} INFO - 2026-05-21 12:39:00,791 - etl.ingest - INFO - Iniciando proceso de ingesta
[2026-05-21, 15:39:00 UTC] {subprocess.py:106} INFO - 2026-05-21 12:39:00,792 - etl.ingest - INFO - Procesando clase: Asma
[2026-05-21, 15:39:00 UTC] {subprocess.py:106} INFO - 2026-05-21 12:39:00,793 - etl.ingest - INFO - Procesando clase: Epoc
[2026-05-21, 15:39:00 UTC] {subprocess.py:106} INFO - 2026-05-21 12:39:00,793 - etl.ingest - INFO - Procesando clase: Neumonia
[2026-05-21, 15:39:00 UTC] {subprocess.py:106} INFO - 2026-05-21 12:39:00,794 - etl.ingest - INFO - Procesando clase: Normal
[2026-05-21, 15:39:00 UTC] {subprocess.py:106} INFO - 2026-05-21 12:39:00,795 - etl.ingest - INFO - Total audios cargados: 240
[2026-05-21, 15:39:01 UTC] {subprocess.py:106} INFO - WARNING: Using incubator modules: jdk.incubator.vector
[2026-05-21, 15:39:03 UTC] {subprocess.py:106} INFO - Using Spark's default log4j profile: org/apache/spark/log4j2-defaults.properties
[2026-05-21, 15:39:03 UTC] {subprocess.py:106} INFO - 26/05/21 12:39:03 WARN Utils: Your hostname, DESKTOP-D5DRVDO, resolves to a loopback address: 127.0.1.1; using 172.18.78.22 instead (on interface eth0)
[2026-05-21, 15:39:03 UTC] {subprocess.py:106} INFO - 26/05/21 12:39:03 WARN Utils: Set SPARK_LOCAL_IP if you need to bind to another address
[2026-05-21, 15:39:05 UTC] {subprocess.py:106} INFO - Using Spark's default log4j profile: org/apache/spark/log4j2-defaults.properties
[2026-05-21, 15:39:05 UTC] {subprocess.py:106} INFO - Setting default log level to "WARN".
[2026-05-21, 15:39:05 UTC] {subprocess.py:106} INFO - To adjust logging level use sc.setLogLevel(newLevel). For SparkR, use setLogLevel(newLevel).
[2026-05-21, 15:39:06 UTC] {subprocess.py:106} INFO - 26/05/21 12:39:06 WARN NativeCodeLoader: Unable to load native-hadoop library for your platform... using builtin-java classes where applicable
[2026-05-21, 15:39:12 UTC] {subprocess.py:106} INFO - 2026-05-21 12:39:12,607 - etl.mfcc_pyspark - INFO - Iniciando pipeline MFCC con PySpark
[2026-05-21, 15:39:13 UTC] {subprocess.py:106} INFO - 2026-05-21 12:39:13,947 - etl.mfcc_pyspark - INFO - DataFrame Spark creado correctamente
[2026-05-21, 15:39:13 UTC] {subprocess.py:106} INFO - /home/tolaba/end-to-end-pipeline-audio-IA/.venv/lib/python3.10/site-packages/pyspark/sql/udf.py:134: UserWarning: Cannot infer the eval type from type hints.
[2026-05-21, 15:39:13 UTC] {subprocess.py:106} INFO -   warnings.warn("Cannot infer the eval type from type hints. ", UserWarning)
[2026-05-21, 15:39:13 UTC] {subprocess.py:106} INFO - 2026-05-21 12:39:13,951 - etl.mfcc_pyspark - INFO - Aplicando extracción MFCC
[2026-05-21, 15:39:14 UTC] {subprocess.py:106} INFO - 2026-05-21 12:39:14,072 - etl.mfcc_pyspark - INFO - MFCC generados correctamente
[2026-05-21, 15:39:14 UTC] {subprocess.py:106} INFO - 2026-05-21 12:39:14,073 - etl.save_parquet - INFO - Iniciando guardado parquet en: data/processed
[2026-05-21, 15:39:32 UTC] {subprocess.py:106} INFO - 
[Stage 0:>                                                          (0 + 1) / 1]
                                                                                
[Stage 1:>                                                          (0 + 4) / 4]
[Stage 1:==============>                                            (1 + 3) / 4]
                                                                                
[2026-05-21, 15:39:34 UTC] {subprocess.py:106} INFO - +----------+-----+--------------------+--------------------+
[2026-05-21, 15:39:34 UTC] {subprocess.py:106} INFO - |class_name|label|                path|                mfcc|
[2026-05-21, 15:39:34 UTC] {subprocess.py:106} INFO - +----------+-----+--------------------+--------------------+
[2026-05-21, 15:39:34 UTC] {subprocess.py:106} INFO - |      Asma|    0|data/raw/Asma/BP7...|[-407.148, -474.1...|
[2026-05-21, 15:39:34 UTC] {subprocess.py:106} INFO - |      Asma|    0|data/raw/Asma/BP3...|[-423.8708, -454....|
[2026-05-21, 15:39:34 UTC] {subprocess.py:106} INFO - |      Asma|    0|data/raw/Asma/BP2...|[-160.73915, -228...|
[2026-05-21, 15:39:34 UTC] {subprocess.py:106} INFO - |      Asma|    0|data/raw/Asma/BP2...|[-502.26944, -498...|
[2026-05-21, 15:39:34 UTC] {subprocess.py:106} INFO - |      Asma|    0|data/raw/Asma/BP2...|[-494.90118, -506...|
[2026-05-21, 15:39:34 UTC] {subprocess.py:106} INFO - +----------+-----+--------------------+--------------------+
[2026-05-21, 15:39:34 UTC] {subprocess.py:106} INFO - only showing top 5 rows
[2026-05-21, 15:39:34 UTC] {subprocess.py:106} INFO - 2026-05-21 12:39:34,045 - py4j.clientserver - INFO - Closing down clientserver connection
